# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.feature_selection import f_classif,SelectKBest,chi2
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.decomposition import PCA
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
firewall = pd.read_csv("C:\\Users\\dharu\\OneDrive\\Desktop\\ISROSpaceHackathon\\firewall.csv")
# Out:
# C:\Users\dharu\AppData\Local\Temp\ipykernel_10448\2255539360.py:1: DtypeWarning: Columns (49,58,59,60,62,63,64,65,66,67,69,70,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   firewall = pd.read_csv("C:\\Users\\dharu\\OneDrive\\Desktop\\ISROSpaceHackathon\\firewall.csv")

# %%
firewall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 74 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   logver            380837 non-null  int64
#  1   timestamp         380837 non-null  int64
#  2   tz                380837 non-null  object
#  3   devname           380837 non-null  object
#  4   devid             380837 non-null  object
#  5   vd                380837 non-null  object
#  6   date              380837 non-null  object
#  7   time              380837 non-null  object
#  8   logid             380837 non-null  object
#  9   type              380837 non-null  object
#  10  subtype           380837 non-null  object
#  11  level             380837 non-null  object
#  12  eventtime         380837 non-null  int64
#  13  srcip             378837 non-null  object
#  14  srcport           284987 non-null  float64
#  15  srcintf           378837 non-null  object
#  16  srcintfrole       378837 non-null  object
#  17  dstip             378837 non-null  object
#  18  dstport           284987 non-null  float64
#  19  dstintf           378837 non-null  object
#  20  dstintfrole       378837 non-null  object
#  21  poluuid           378528 non-null  object
#  22  sessionid         378837 non-null  float64
#  23  proto             378837 non-null  float64
#  24  action            378977 non-null  object
#  25  policyid          378837 non-null  float64
#  26  policytype        378528 non-null  object
#  27  service           378837 non-null  object
#  28  dstcountry        378495 non-null  object
#  29  srccountry        378498 non-null  object
#  30  trandisp          378495 non-null  object
#  31  duration          378495 non-null  float64
#  32  sentbyte          378495 non-null  float64
#  33  rcvdbyte          378495 non-null  float64
#  34  sentpkt           378495 non-null  float64
#  35  appcat            378834 non-null  object
#  36  rcvdpkt           229304 non-null  float64
#  37  wanin             32624 non-null   float64
#  38  wanout            32624 non-null   float64
#  39  lanin             32624 non-null   float64
#  40  lanout            32624 non-null   float64
#  41  sentdelta         12862 non-null   float64
#  42  rcvddelta         12862 non-null   float64
#  43  crscore           16791 non-null   float64
#  44  craction          16788 non-null   float64
#  45  crlevel           16788 non-null   object
#  46  logdesc           2000 non-null    object
#  47  hostname          1859 non-null    object
#  48  msg               2003 non-null    object
#  49  app               306 non-null     object
#  50  cpu               124 non-null     float64
#  51  mem               124 non-null     float64
#  52  totalsession      124 non-null     float64
#  53  disk              124 non-null     float64
#  54  bandwidth         124 non-null     object
#  55  setuprate         124 non-null     float64
#  56  disklograte       124 non-null     float64
#  57  fazlograte        124 non-null     float64
#  58  user              10 non-null      object
#  59  ui                10 non-null      object
#  60  status            11 non-null      object
#  61  count             10 non-null      float64
#  62  reason            6 non-null       object
#  63  log               6 non-null       object
#  64  eventtype         3 non-null       object
#  65  severity          3 non-null       object
#  66  attack            3 non-null       object
#  67  direction         3 non-null       object
#  68  attackid          3 non-null       float64
#  69  profile           3 non-null       object
#  70  ref               3 non-null       object
#  71  incidentserialno  3 non-null       float64
#  72  utmaction         3 non-null       object
#  73  countips          3 non-null       float64
# dtypes: float64(29), int64(3), object(42)
# memory usage: 215.0+ MB

# %%
df = firewall.copy()

# %%
numerical_features = ['srcport', 'dstport', 'sessionid', 'proto', 'policyid', 'duration', 'sentbyte', 'rcvdbyte', 'sentpkt', 'rcvdpkt', 'wanin', 'wanout', 'lanin', 'lanout', 'sentdelta', 'rcvddelta', 'crscore', 'craction', 'cpu', 'mem', 'totalsession', 'disk', 'setuprate', 'disklograte', 'fazlograte', 'count', 'incidentserialno', 'countips']
df[numerical_features] = df[numerical_features].fillna(df[numerical_features].mean())

# %%
categorical_features = ['srcip', 'srcintf', 'srcintfrole', 'dstip', 'dstintf', 'dstintfrole', 'poluuid', 'action', 'policytype', 'dstcountry', 'srccountry', 'trandisp', 'appcat', 'user', 'ui', 'status', 'reason', 'log', 'eventtype', 'severity', 'attack', 'direction', 'profile', 'ref', 'utmaction', 'bandwidth']
df[categorical_features] = df[categorical_features].fillna(method='ffill')

# %%
columns_to_drop = ['logdesc', 'hostname', 'msg', 'app', 'cpu', 'mem', 'totalsession', 'disk', 'bandwidth', 'user', 'ui', 'status', 'count', 'reason', 'log', 'eventtype', 'severity', 'attack', 'direction', 'attackid', 'profile', 'ref', 'incidentserialno', 'utmaction', 'countips']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 49 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   logver       380837 non-null  int64
#  1   timestamp    380837 non-null  int64
#  2   tz           380837 non-null  object
#  3   devname      380837 non-null  object
#  4   devid        380837 non-null  object
#  5   vd           380837 non-null  object
#  6   date         380837 non-null  object
#  7   time         380837 non-null  object
#  8   logid        380837 non-null  object
#  9   type         380837 non-null  object
#  10  subtype      380837 non-null  object
#  11  level        380837 non-null  object
#  12  eventtime    380837 non-null  int64
#  13  srcip        380837 non-null  object
#  14  srcport      380837 non-null  float64
#  15  srcintf      380837 non-null  object
#  16  srcintfrole  380837 non-null  object
#  17  dstip        380837 non-null  object
#  18  dstport      380837 non-null  float64
#  19  dstintf      380837 non-null  object
#  20  dstintfrole  380837 non-null  object
#  21  poluuid      380837 non-null  object
#  22  sessionid    380837 non-null  float64
#  23  proto        380837 non-null  float64
#  24  action       380837 non-null  object
#  25  policyid     380837 non-null  float64
#  26  policytype   380837 non-null  object
#  27  service      378837 non-null  object
#  28  dstcountry   380837 non-null  object
#  29  srccountry   380837 non-null  object
#  30  trandisp     380837 non-null  object
#  31  duration     380837 non-null  float64
#  32  sentbyte     380837 non-null  float64
#  33  rcvdbyte     380837 non-null  float64
#  34  sentpkt      380837 non-null  float64
#  35  appcat       380837 non-null  object
#  36  rcvdpkt      380837 non-null  float64
#  37  wanin        380837 non-null  float64
#  38  wanout       380837 non-null  float64
#  39  lanin        380837 non-null  float64
#  40  lanout       380837 non-null  float64
#  41  sentdelta    380837 non-null  float64
#  42  rcvddelta    380837 non-null  float64
#  43  crscore      380837 non-null  float64
#  44  craction     380837 non-null  float64
#  45  crlevel      16788 non-null   object
#  46  setuprate    380837 non-null  float64
#  47  disklograte  380837 non-null  float64
#  48  fazlograte   380837 non-null  float64
# dtypes: float64(21), int64(3), object(25)
# memory usage: 142.4+ MB

# %%
df[["service","crlevel"]] = df[["service","crlevel"]].fillna(method='ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 49 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   logver       380837 non-null  int64
#  1   timestamp    380837 non-null  int64
#  2   tz           380837 non-null  object
#  3   devname      380837 non-null  object
#  4   devid        380837 non-null  object
#  5   vd           380837 non-null  object
#  6   date         380837 non-null  object
#  7   time         380837 non-null  object
#  8   logid        380837 non-null  object
#  9   type         380837 non-null  object
#  10  subtype      380837 non-null  object
#  11  level        380837 non-null  object
#  12  eventtime    380837 non-null  int64
#  13  srcip        380837 non-null  object
#  14  srcport      380837 non-null  float64
#  15  srcintf      380837 non-null  object
#  16  srcintfrole  380837 non-null  object
#  17  dstip        380837 non-null  object
#  18  dstport      380837 non-null  float64
#  19  dstintf      380837 non-null  object
#  20  dstintfrole  380837 non-null  object
#  21  poluuid      380837 non-null  object
#  22  sessionid    380837 non-null  float64
#  23  proto        380837 non-null  float64
#  24  action       380837 non-null  object
#  25  policyid     380837 non-null  float64
#  26  policytype   380837 non-null  object
#  27  service      380837 non-null  object
#  28  dstcountry   380837 non-null  object
#  29  srccountry   380837 non-null  object
#  30  trandisp     380837 non-null  object
#  31  duration     380837 non-null  float64
#  32  sentbyte     380837 non-null  float64
#  33  rcvdbyte     380837 non-null  float64
#  34  sentpkt      380837 non-null  float64
#  35  appcat       380837 non-null  object
#  36  rcvdpkt      380837 non-null  float64
#  37  wanin        380837 non-null  float64
#  38  wanout       380837 non-null  float64
#  39  lanin        380837 non-null  float64
#  40  lanout       380837 non-null  float64
#  41  sentdelta    380837 non-null  float64
#  42  rcvddelta    380837 non-null  float64
#  43  crscore      380837 non-null  float64
#  44  craction     380837 non-null  float64
#  45  crlevel      380773 non-null  object
#  46  setuprate    380837 non-null  float64
#  47  disklograte  380837 non-null  float64
#  48  fazlograte   380837 non-null  float64
# dtypes: float64(21), int64(3), object(25)
# memory usage: 142.4+ MB

# %%
df["crlevel"] = df["crlevel"].fillna(method='ffill')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 49 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   logver       380837 non-null  int64
#  1   timestamp    380837 non-null  int64
#  2   tz           380837 non-null  object
#  3   devname      380837 non-null  object
#  4   devid        380837 non-null  object
#  5   vd           380837 non-null  object
#  6   date         380837 non-null  object
#  7   time         380837 non-null  object
#  8   logid        380837 non-null  object
#  9   type         380837 non-null  object
#  10  subtype      380837 non-null  object
#  11  level        380837 non-null  object
#  12  eventtime    380837 non-null  int64
#  13  srcip        380837 non-null  object
#  14  srcport      380837 non-null  float64
#  15  srcintf      380837 non-null  object
#  16  srcintfrole  380837 non-null  object
#  17  dstip        380837 non-null  object
#  18  dstport      380837 non-null  float64
#  19  dstintf      380837 non-null  object
#  20  dstintfrole  380837 non-null  object
#  21  poluuid      380837 non-null  object
#  22  sessionid    380837 non-null  float64
#  23  proto        380837 non-null  float64
#  24  action       380837 non-null  object
#  25  policyid     380837 non-null  float64
#  26  policytype   380837 non-null  object
#  27  service      380837 non-null  object
#  28  dstcountry   380837 non-null  object
#  29  srccountry   380837 non-null  object
#  30  trandisp     380837 non-null  object
#  31  duration     380837 non-null  float64
#  32  sentbyte     380837 non-null  float64
#  33  rcvdbyte     380837 non-null  float64
#  34  sentpkt      380837 non-null  float64
#  35  appcat       380837 non-null  object
#  36  rcvdpkt      380837 non-null  float64
#  37  wanin        380837 non-null  float64
#  38  wanout       380837 non-null  float64
#  39  lanin        380837 non-null  float64
#  40  lanout       380837 non-null  float64
#  41  sentdelta    380837 non-null  float64
#  42  rcvddelta    380837 non-null  float64
#  43  crscore      380837 non-null  float64
#  44  craction     380837 non-null  float64
#  45  crlevel      380837 non-null  object
#  46  setuprate    380837 non-null  float64
#  47  disklograte  380837 non-null  float64
#  48  fazlograte   380837 non-null  float64
# dtypes: float64(21), int64(3), object(25)
# memory usage: 142.4+ MB

# %%
# Scoring criteria
criteria = {
    'duration': {'safe': 600, 'moderately_safe': 1800, 'unsafe': 3600},
    'sentbyte': {'safe': 1e8, 'moderately_safe': 5e7, 'unsafe': 1e7},
    'crscore': {'safe': 80, 'moderately_safe': 60, 'unsafe': 0},
}

# %%
def categorize(row):
    max_category = 'unknown'
    max_threshold = 0
    for feature, thresholds in criteria.items():
        if pd.notna(row[feature]):  # Skip NaN values
            for category, threshold in thresholds.items():
                if row[feature] >= threshold and threshold > max_threshold:
                    max_threshold = threshold
                    max_category = category     
    return max_category

# %%
df['category'] = df.apply(categorize, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 50 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   logver       380837 non-null  int64
#  1   timestamp    380837 non-null  int64
#  2   tz           380837 non-null  object
#  3   devname      380837 non-null  object
#  4   devid        380837 non-null  object
#  5   vd           380837 non-null  object
#  6   date         380837 non-null  object
#  7   time         380837 non-null  object
#  8   logid        380837 non-null  object
#  9   type         380837 non-null  object
#  10  subtype      380837 non-null  object
#  11  level        380837 non-null  object
#  12  eventtime    380837 non-null  int64
#  13  srcip        380837 non-null  object
#  14  srcport      380837 non-null  float64
#  15  srcintf      380837 non-null  object
#  16  srcintfrole  380837 non-null  object
#  17  dstip        380837 non-null  object
#  18  dstport      380837 non-null  float64
#  19  dstintf      380837 non-null  object
#  20  dstintfrole  380837 non-null  object
#  21  poluuid      380837 non-null  object
#  22  sessionid    380837 non-null  float64
#  23  proto        380837 non-null  float64
#  24  action       380837 non-null  object
#  25  policyid     380837 non-null  float64
#  26  policytype   380837 non-null  object
#  27  service      380837 non-null  object
#  28  dstcountry   380837 non-null  object
#  29  srccountry   380837 non-null  object
#  30  trandisp     380837 non-null  object
#  31  duration     380837 non-null  float64
#  32  sentbyte     380837 non-null  float64
#  33  rcvdbyte     380837 non-null  float64
#  34  sentpkt      380837 non-null  float64
#  35  appcat       380837 non-null  object
#  36  rcvdpkt      380837 non-null  float64
#  37  wanin        380837 non-null  float64
#  38  wanout       380837 non-null  float64
#  39  lanin        380837 non-null  float64
#  40  lanout       380837 non-null  float64
#  41  sentdelta    380837 non-null  float64
#  42  rcvddelta    380837 non-null  float64
#  43  crscore      380837 non-null  float64
#  44  craction     380837 non-null  float64
#  45  crlevel      380837 non-null  object
#  46  setuprate    380837 non-null  float64
#  47  disklograte  380837 non-null  float64
#  48  fazlograte   380837 non-null  float64
#  49  category     380837 non-null  object
# dtypes: float64(21), int64(3), object(26)
# memory usage: 145.3+ MB

# %%
df.head()
# Out:
#       logver   timestamp          tz        devname               devid  \
# 0  506141727  1698690294  "UTC+5:30"  "FGT3600C_HA"  "FG3K6C3A15800081"
# 1  506141727  1698690294  "UTC+5:30"  "FGT3600C_HA"  "FG3K6C3A15800081"
# 2  506141727  1698690294  "UTC+5:30"  "FGT3600C_HA"  "FG3K6C3A15800081"
# 3  506141727  1698690294  "UTC+5:30"  "FGT3600C_HA"  "FG3K6C3A15800081"
# 4  506141727  1698690295  "UTC+5:30"  "FGT3600C_HA"  "FG3K6C3A15800081"
#
#        vd        date      time         logid       type  ...       lanout  \
# 0  "root"  2023-10-30  23:54:54  "0000000013"  "traffic"  ...  1067.812715
# 1  "root"  2023-10-30  23:54:54  "0000000013"  "traffic"  ...  1067.812715
# 2  "root"  2023-10-30  23:54:54  "0000000013"  "traffic"  ...  1148.000000
# 3  "root"  2023-10-30  23:54:54  "0000000013"  "traffic"  ...  1067.812715
# 4  "root"  2023-10-30  23:54:55  "0000000013"  "traffic"  ...  1148.000000
#
#      sentdelta     rcvddelta    crscore      craction crlevel  setuprate  \
# 0  1721.717462  87030.892007  20.254005  182180.75006  "high"  18.145161
# 1  1721.717462  87030.892007  20.254005  182180.75006  "high"  18.145161
# 2  1721.717462  87030.892007  20.254005  182180.75006  "high"  18.145161
# 3  1721.717462  87030.892007  20.254005  182180.75006  "high"  18.145161
# 4  1721.717462  87030.892007  20.254005  182180.75006  "high"  18.145161
#
#   disklograte  fazlograte category
# 0         0.0    14.91129  unknown
# 1         0.0    14.91129  unknown
# 2         0.0    14.91129  unknown
# 3         0.0    14.91129  unknown
# 4         0.0    14.91129  unknown
#
# [5 rows x 50 columns]

# %%
df["category"].value_counts()
# Out:
# unknown            379360
# safe                  744
# unsafe                383
# moderately_safe       350
# Name: category, dtype: int64

# %%
ob = []
fl = []
num = []
for i in df.columns:
    if df[i].dtype == "object":
        ob.append(i)
for i in df.columns:
    if df[i].dtype == "int64":
        num.append(i)
for i in df.columns:
    if df[i].dtype == "float64":
        fl.append(i)
print(fl)
print(num)
print(ob)
# Out:
# ['srcport', 'dstport', 'sessionid', 'proto', 'policyid', 'duration', 'sentbyte', 'rcvdbyte', 'sentpkt', 'rcvdpkt', 'wanin', 'wanout', 'lanin', 'lanout', 'sentdelta', 'rcvddelta', 'crscore', 'craction', 'setuprate', 'disklograte', 'fazlograte']
# ['logver', 'timestamp', 'eventtime']
# ['tz', 'devname', 'devid', 'vd', 'date', 'time', 'logid', 'type', 'subtype', 'level', 'srcip', 'srcintf', 'srcintfrole', 'dstip', 'dstintf', 'dstintfrole', 'poluuid', 'action', 'policytype', 'service', 'dstcountry', 'srccountry', 'trandisp', 'appcat', 'crlevel', 'category']

# %%
lab = LabelEncoder()
mod_data = df.copy()
for i in ob:
    mod_data[i] = lab.fit_transform(mod_data[i])

# %%
mod_data.head()
# Out:
#       logver   timestamp  tz  devname  devid  vd  date   time  logid  type  \
# 0  506141727  1698690294   0        0      1   0     0  18376      1     1
# 1  506141727  1698690294   0        0      1   0     0  18376      1     1
# 2  506141727  1698690294   0        0      1   0     0  18376      1     1
# 3  506141727  1698690294   0        0      1   0     0  18376      1     1
# 4  506141727  1698690295   0        0      1   0     0  18377      1     1
#
#    ...       lanout    sentdelta     rcvddelta    crscore      craction  \
# 0  ...  1067.812715  1721.717462  87030.892007  20.254005  182180.75006
# 1  ...  1067.812715  1721.717462  87030.892007  20.254005  182180.75006
# 2  ...  1148.000000  1721.717462  87030.892007  20.254005  182180.75006
# 3  ...  1067.812715  1721.717462  87030.892007  20.254005  182180.75006
# 4  ...  1148.000000  1721.717462  87030.892007  20.254005  182180.75006
#
#    crlevel  setuprate  disklograte  fazlograte  category
# 0        1  18.145161          0.0    14.91129         2
# 1        1  18.145161          0.0    14.91129         2
# 2        1  18.145161          0.0    14.91129         2
# 3        1  18.145161          0.0    14.91129         2
# 4        1  18.145161          0.0    14.91129         2
#
# [5 rows x 50 columns]

# %%
features = []
for i in mod_data.columns:
    if i != "category":
        features.append(i)
X = mod_data[features]
y = mod_data["category"]

# %%
mod_data.corr()
# Out:
#              logver  timestamp  tz  devname         devid  vd      date  \
# logver          NaN        NaN NaN      NaN           NaN NaN       NaN
# timestamp       NaN   1.000000 NaN      NaN -3.005293e-03 NaN  0.255622
# tz              NaN        NaN NaN      NaN           NaN NaN       NaN
# devname         NaN        NaN NaN      NaN           NaN NaN       NaN
# devid           NaN  -0.003005 NaN      NaN  1.000000e+00 NaN -0.001679
# vd              NaN        NaN NaN      NaN           NaN NaN       NaN
# date            NaN   0.255622 NaN      NaN -1.679253e-03 NaN  1.000000
# time            NaN   0.809355 NaN      NaN -1.879247e-03 NaN -0.360918
# logid           NaN   0.022812 NaN      NaN -1.956723e-01 NaN  0.005190
# type            NaN  -0.023440 NaN      NaN  1.904222e-01 NaN -0.007892
# subtype         NaN   0.025092 NaN      NaN -1.843522e-01 NaN  0.008065
# level           NaN  -0.020956 NaN      NaN -7.285922e-04 NaN -0.011514
# eventtime       NaN   1.000000 NaN      NaN -3.005287e-03 NaN  0.255622
# srcip           NaN   0.094857 NaN      NaN -8.083712e-04 NaN  0.039131
# srcport         NaN  -0.087467 NaN      NaN -1.139831e-13 NaN -0.021991
# srcintf         NaN  -0.102662 NaN      NaN -4.591001e-03 NaN  0.004893
# srcintfrole     NaN   0.107832 NaN      NaN  4.822613e-03 NaN -0.004802
# dstip           NaN   0.071328 NaN      NaN  2.539692e-03 NaN -0.005246
# dstport         NaN   0.055738 NaN      NaN  6.215846e-14 NaN  0.024343
# dstintf         NaN   0.107954 NaN      NaN  4.827515e-03 NaN -0.004757
# dstintfrole     NaN  -0.107954 NaN      NaN -4.827515e-03 NaN  0.004757
# poluuid         NaN   0.011524 NaN      NaN -1.895067e-03 NaN  0.019303
# sessionid       NaN   0.816228 NaN      NaN  1.162141e-12 NaN  0.242311
# proto           NaN  -0.144366 NaN      NaN -1.649330e-13 NaN -0.056283
# action          NaN  -0.109122 NaN      NaN -2.707896e-02 NaN -0.044265
# policyid        NaN  -0.015443 NaN      NaN -2.157835e-14 NaN  0.003466
# policytype      NaN        NaN NaN      NaN           NaN NaN       NaN
# service         NaN   0.029368 NaN      NaN  2.572816e-04 NaN  0.016765
# dstcountry      NaN   0.114282 NaN      NaN  4.143878e-03 NaN -0.001300
# fazlograte   8.673825e-01          NaN  1.000000e+00 -3.324255e-15
# category    -1.143291e-14          NaN -3.324255e-15  1.000000e+00
#
# [50 rows x 50 columns]

# %%
sel = SelectKBest(score_func = f_classif,k = 12)
ch = SelectKBest(score_func = chi2,k=12)
data = sel.fit_transform(X,y)
ch_data = ch.fit_transform(X,y)
mod_features = sel.get_support()
ch_features = ch.get_support()
f_cl = X.columns[mod_features]
chi_cl = X.columns[ch_features]
# Out:
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [ 2  3  5 26 30 35 47] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
smote = SMOTE(random_state=42)
X_train_f,X_test_f,y_train_f,y_test_f = train_test_split(X[f_cl],y) #Features found using f score
X_train_chi,X_test_chi,y_train_chi,y_test_chi = train_test_split(X[chi_cl],y) #Features found using chi2 scores
X_resampled_chi, y_resampled_chi = smote.fit_resample(X_train_chi, y_train_chi) #Resampling for f score based features
X_resampled_f, y_resampled_f = smote.fit_resample(X_train_f, y_train_f) #Resampling for chi square based features

# %%
log = LogisticRegression()
log.fit(X_resampled_chi,y_resampled_chi)
# Out:
# LogisticRegression()

# %%
print(classification_report(log.predict(X_test_chi),y_test_chi))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.06      0.11      1404
#            1       0.47      0.06      0.11      1557
#            2       0.97      1.00      0.98     91874
#            3       0.50      0.13      0.21       375
#
#     accuracy                           0.97     95210
#    macro avg       0.67      0.31      0.35     95210
# weighted avg       0.96      0.97      0.95     95210

# %%
dec = DecisionTreeClassifier()
dec.fit(X_resampled_chi,y_resampled_chi)
# Out:
# DecisionTreeClassifier()

# %%
print(classification_report(y_test_chi,dec.predict(X_test_chi)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       108
#            1       1.00      1.00      1.00       198
#            2       1.00      1.00      1.00     94806
#            3       1.00      1.00      1.00        98
#
#     accuracy                           1.00     95210
#    macro avg       1.00      1.00      1.00     95210
# weighted avg       1.00      1.00      1.00     95210

# %%
ada = AdaBoostClassifier()
ada.fit(X_resampled_chi,y_resampled_chi)
# Out:
# AdaBoostClassifier()

# %%
print(classification_report(y_test_chi,ada.predict(X_test_chi)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      1.00      0.52       108
#            1       0.00      0.00      0.00       198
#            2       1.00      1.00      1.00     94806
#            3       1.00      1.00      1.00        98
#
#     accuracy                           1.00     95210
#    macro avg       0.59      0.75      0.63     95210
# weighted avg       1.00      1.00      1.00     95210
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
ran = RandomForestClassifier()
ran.fit(X_resampled_f,y_resampled_f)
# Out:
# RandomForestClassifier()

# %%
print(classification_report(y_test_f,ran.predict(X_test_f)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        91
#            1       1.00      0.99      1.00       189
#            2       1.00      1.00      1.00     94835
#            3       1.00      1.00      1.00        95
#
#     accuracy                           1.00     95210
#    macro avg       1.00      1.00      1.00     95210
# weighted avg       1.00      1.00      1.00     95210

# %%
pc = PCA(n_components = 12)
feats = pc.fit_transform(X)

# %%
feature_contributions = pd.DataFrame(pc.components_, columns=X.columns)
feature_contributions
# Out:
#           logver  timestamp            tz       devname         devid  \
# 0   0.000000e+00   0.000035  0.000000e+00  0.000000e+00 -2.709384e-17
# 1  -1.294537e-16  -0.000054 -0.000000e+00 -0.000000e+00  1.798107e-16
# 2   6.854191e-18  -0.017640  0.000000e+00  0.000000e+00  1.561328e-13
# 1   1.984804e-06  2.864572e-09  7.503602e-15         -0.0  4.745544e-15
# 2   3.558091e-03  2.466110e-07  6.057653e-12          0.0  3.823446e-12
# 3   3.610668e-04  1.633635e-09  4.448935e-12          0.0  2.815404e-12
# 4  -2.334834e-01 -1.159552e-06  1.447747e-09          0.0  9.502130e-10
# 5  -9.626473e-01 -7.204200e-06 -2.697771e-09         -0.0 -1.648176e-09
# 6   3.610249e-02 -6.360391e-06 -3.002545e-07         -0.0 -1.871996e-07
# 7   1.300573e-01  6.753568e-06  6.051209e-08          0.0  4.262234e-08
# 8   2.355868e-02  2.584588e-06 -3.109450e-07         -0.0 -2.031001e-07
# 9  -2.010263e-03 -1.273331e-06  1.184059e-07          0.0  5.646490e-09
# 10  1.198704e-03  6.819026e-06  7.538394e-06          0.0  5.042219e-06
# 11 -4.212387e-05  1.181912e-06 -4.671177e-06          0.0 -3.108376e-06
#
# [12 rows x 49 columns]

# %%
most_important_features = feature_contributions.idxmax(axis=1)

# %%
pca_analyzed = []
for i, feature in enumerate(most_important_features):
    pca_analyzed.append(feature)
pca_analyzed
# Out:
# ['rcvdbyte',
#  'rcvddelta',
#  'sentbyte',
#  'rcvddelta',
#  'srcport',
#  'dstport',
#  'time',
#  'dstport',
#  'dstport',
#  'sentbyte',
#  'sentbyte',
#  'wanout']

# %%
smote = SMOTE(random_state=42)
X_train_pc,X_test_pc,y_train_pc,y_test_pc = train_test_split(X[pca_analyzed],y) #Features found using PCA Analysis
X_resampled_pc, y_resampled_pc = smote.fit_resample(X_train_pc, y_train_pc)

# %%
log.fit(X_resampled_pc,y_resampled_pc)
# Out:
# C:\Users\dharu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(classification_report(y_test_pc,log.predict(X_test_pc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.26      0.88      0.40        86
#            1       0.05      0.53      0.09       178
#            2       1.00      0.98      0.99     94841
#            3       0.38      0.77      0.51       105
#
#     accuracy                           0.98     95210
#    macro avg       0.42      0.79      0.50     95210
# weighted avg       1.00      0.98      0.99     95210

# %%
ran.fit(X_resampled_pc,y_resampled_pc)
# Out:
# RandomForestClassifier()

# %%
print(classification_report(y_test_pc,ran.predict(X_test_pc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88        86
#            1       0.67      0.79      0.72       178
#            2       1.00      1.00      1.00     94841
#            3       0.91      0.94      0.93       105
#
#     accuracy                           1.00     95210
#    macro avg       0.86      0.91      0.88     95210
# weighted avg       1.00      1.00      1.00     95210

# %%
dec.fit(X_resampled_pc,y_resampled_pc)
# Out:
# DecisionTreeClassifier()

# %%
print(classification_report(y_test_pc,dec.predict(X_test_pc)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83        86
#            1       0.58      0.76      0.66       178
#            2       1.00      1.00      1.00     94841
#            3       0.90      0.90      0.90       105
#
#     accuracy                           1.00     95210
#    macro avg       0.81      0.89      0.85     95210
# weighted avg       1.00      1.00      1.00     95210

# %%
print(X_resampled_pc.shape)
print(y_resampled_pc.shape)
# Out:
# (1138076, 12)
# (1138076,)

# %%
y_resampled_pc_onehot = to_categorical(y_resampled_pc, num_classes=4)
X_train, X_test, y_train, y_test = train_test_split(X_resampled_pc, y_resampled_pc_onehot, test_size=0.2, random_state=42)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(4, activation='softmax'))  # Use softmax for 4 classes
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2