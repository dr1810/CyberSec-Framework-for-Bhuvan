# %%
import pandas as pd
import numpy as np

# %%
file = open("C:/Users/dharu/OneDrive/Desktop/ISROSpaceHackathon/topic04/firewall logs/31Oct2023-messages.txt")
content = file.readlines()

# %%
content[0].split()
# Out:
# ['2023-10-30T23:56:11.890671+05:30',
#  '172.26.5.193',
#  'logver=506141727',
#  'timestamp=1698690294',
#  'tz="UTC+5:30"',
#  'devname="FGT3600C_HA"',
#  'devid="FG3K6C3A15800081"',
#  'vd="root"',
#  'date=2023-10-30',
#  'time=23:54:54',
#  'logid="0000000013"',
#  'type="traffic"',
#  'subtype="forward"',
#  'level="notice"',
#  'eventtime=1698690294',
#  'srcip=103.81.182.133',
#  'srcport=30390',
#  'srcintf="LLB-',
#  'Connect"',
#  'srcintfrole="wan"',
#  'dstip=172.26.2.51',
#  'dstport=443',
#  'dstintf="Local_LAN"',
#  'dstintfrole="undefined"',
#  'poluuid="3367bf4c-74ff-51e8-3e96-72b0684b3e81"',
#  'sessionid=1943252826',
#  'proto=6',
#  'action="client-rst"',
#  'policyid=49',
#  'policytype="policy"',
#  'service="HTTPS"',
#  'dstcountry="Reserved"',
#  'srccountry="India"',
#  'trandisp="noop"',
#  'duration=13',
#  'sentbyte=1097',
#  'rcvdbyte=9182',
#  'sentpkt=11',
#  'appcat="unscanned"']

# %%
columns = []
for j in range(len(content)):
    dt = {}
    for i in content[j].split():
        if '=' in i:
            new = i.split('=')
            dt[new[0]] = new[1]
    columns.append(dt)
columns
# Out:
# [{'logver': '506141727',
#   'timestamp': '1698690294',
#   'tz': '"UTC+5:30"',
#   'devname': '"FGT3600C_HA"',
#   'devid': '"FG3K6C3A15800081"',
#   'vd': '"root"',
#   'date': '2023-10-30',
#   'time': '23:54:54',
#   'logid': '"0000000013"',
#   'type': '"traffic"',
#   'subtype': '"forward"',
#   'level': '"notice"',
#   'eventtime': '1698690294',
#   'srcip': '103.81.182.133',
#   'srcport': '30390',
#   'srcintf': '"LLB-',
#   'srcintfrole': '"wan"',
#   'dstip': '172.26.2.51',
#   'dstport': '443',
#   'dstintf': '"Local_LAN"',
#   'dstintfrole': '"undefined"',
#   'poluuid': '"3367bf4c-74ff-51e8-3e96-72b0684b3e81"',
#   'sessionid': '1943252826',
#   'proto': '6',
#   'action': '"client-rst"',
#   'policyid': '49',
#   'policytype': '"policy"',
#   'service': '"HTTPS"',
#   'dstcountry': '"Reserved"',
#   'srccountry': '"India"',
#   'trandisp': '"noop"',
#   'duration': '13',
#   'sentbyte': '1097',
#   'rcvdbyte': '9182',
#   'sentpkt': '11',
#   'appcat': '"unscanned"'},
# ...

# %%
new = pd.DataFrame(columns)

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 74 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   logver            380837 non-null  object
#  1   timestamp         380837 non-null  object
#  2   tz                380837 non-null  object
#  3   devname           380837 non-null  object
#  4   devid             380837 non-null  object
#  5   vd                380837 non-null  object
#  6   date              380837 non-null  object
#  7   time              380837 non-null  object
#  8   logid             380837 non-null  object
#  9   type              380837 non-null  object
#  10  subtype           380837 non-null  object
#  11  level             380837 non-null  object
#  12  eventtime         380837 non-null  object
#  13  srcip             378837 non-null  object
#  14  srcport           284987 non-null  object
#  15  srcintf           378837 non-null  object
# ...

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380837 entries, 0 to 380836
# Data columns (total 74 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   logver            380837 non-null  object
#  1   timestamp         380837 non-null  object
#  2   tz                380837 non-null  object
#  3   devname           380837 non-null  object
#  4   devid             380837 non-null  object
#  5   vd                380837 non-null  object
#  6   date              380837 non-null  object
#  7   time              380837 non-null  object
#  8   logid             380837 non-null  object
#  9   type              380837 non-null  object
#  10  subtype           380837 non-null  object
#  11  level             380837 non-null  object
#  12  eventtime         380837 non-null  object
#  13  srcip             378837 non-null  object
#  14  srcport           284987 non-null  object
#  15  srcintf           378837 non-null  object
# ...

# %%
new.to_csv("C:/Users/dharu/OneDrive/Desktop/ISROSpaceHackathon/firewall.csv",index = False)

# %%
file.close()

# %%
server = pd.read_csv("C:/Users/dharu/OneDrive/Desktop/ISROSpaceHackathon/server_log_data.csv")

# %%
server.head()
# Out:
#      ip_address                   timestamp method  \
# 0  172.26.3.214  06/Nov/2023:00:00:02 +0530    GET
# 1  172.26.3.214  06/Nov/2023:00:00:02 +0530    GET
# 2  172.26.3.214  06/Nov/2023:00:00:02 +0530    GET
# 3  172.26.3.214  06/Nov/2023:00:00:02 +0530    GET
# 4  172.26.3.214  06/Nov/2023:00:00:02 +0530    GET
#
#                                                  url  protocol  status  size  \
# 0  /scan_m/cas_userstats/getUserStats.php?sdate=2...  HTTP/1.1     200    93
# 1  /scan_m/cas_userstats/getUserStats.php?sdate=2...  HTTP/1.1     200    93
# 2  /scan_m/cas_userstats/getUserStats.php?sdate=2...  HTTP/1.1     200    93
# 3  /scan_m/cas_userstats/getUserStats.php?sdate=2...  HTTP/1.1     200    93
# 4  /scan_m/cas_userstats/getUserStats.php?sdate=2...  HTTP/1.1     200    93
#
#   referer                                         user_agent
# 0       -  python-requests/2.5.1 CPython/3.8.5 Linux/3.10...
# 1       -  python-requests/2.5.1 CPython/3.8.5 Linux/3.10...
# ...

# %%
server.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38993 entries, 0 to 38992
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ip_address  38993 non-null  object
#  1   timestamp   38993 non-null  object
#  2   method      38993 non-null  object
#  3   url         38993 non-null  object
#  4   protocol    38993 non-null  object
#  5   status      38993 non-null  int64
#  6   size        38993 non-null  int64
#  7   referer     38993 non-null  object
#  8   user_agent  38993 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 2.7+ MB
